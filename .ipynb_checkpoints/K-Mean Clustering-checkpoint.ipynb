# %%
##Improting necessary libraries
import pandas  as pd
import matplotlib.pyplot as plt
from collections import Counter
from scipy.spatial.distance import cdist

# %%
data = pd.read_csv('Wholesale customers data.csv')

# %%
data.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
data.head(1)
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338

# %%
data.columns
# Out:
# Index(['Channel', 'Region', 'Fresh', 'Milk', 'Grocery', 'Frozen',
#        'Detergents_Paper', 'Delicassen'],
#       dtype='object')

# %%
## Elbow method
from sklearn.cluster import KMeans
WCSS = []
for i in range(1,101):
    Kmean = KMeans(n_clusters=i, init='k-means++', random_state = 43)
    Kmean.fit(data)
    WCSS.append(Kmean.inertia_)
plt.plot(range(1,101),WCSS)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f69f093a8b0>
# Traceback (most recent call last):
#   File "/home/rajan/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/home/rajan/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/home/rajan/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/home/rajan/anaconda3/lib/python3.9/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# ...

# %%
##fitting kmeans to the dataset
kmeans = KMeans(n_clusters=20, init = 'k-means++',random_state=42)
y_means = kmeans.fit_predict(data)

# %%
print(y_means)
# Out:
# [14 14 14 11  2 14 11 14 16  3  6 11  2  2  2  0  6 16  2 14 11  0  8 15
#   2 11  0 11  3  8  2 16 19  8 16  6  8  2  3  4 19 19 14  3 14  3  3  5
#  14  1  0 16  8  6 19 16  1 14 11 14 14  5 14  3  0  1 16  2 16  0 19  2
#   0 19 14 19 16  1  0 16  0  6 14 19 11 13 12  8 17 19  0 11  1 17 14 16
#  16 16 16  0 14  6 14  4 11 11  6  3 14  3 11  3 19 11 19  0 11  0 19  0
#  11 16 11 14  8  4 19  2 16  8  0 16 11  0  0  0 14 14 11 16 11  8  8  0
#  19  1  0  0  0  8 11 16 19 16 16  3  6 19 14  6  6 11 11  3 14  3 14 16
#   0  0  6  3 16  6 16  6  8 11 11 16 14  9  6 10 16  0 16 14 14  6 19 11
#   0  6  0 19  8  6 11  0  3  3  2 16 16  3  0 16 16  3 19  1  0 14  6  6
#   1 19  6 16 11 14  0 16  0 11  2 16 16  0 11 14 19 16 11 16  0 19  0  8
#  19 19 19 11 14  6  0 11 11  0 16  1  0  2 14  8 11  0  4  4  0  0 19 16
#   6  3  3 19  3 11  0 16 16  8 16 16 19 17 11  2 16 11  4 19  4  8  0 11
#  11  8 16  0 16  6 19  0 19 14 14 16 11  3  6  6  3  6  3 11  0  3 17  8
# ...

# %%
## predict the cluster nuber to with datapoint belongs

# %%
Index(['Channel', 'Region', 'Fresh', 'Milk', 'Grocery', 'Frozen',
       'Detergents_Paper', 'Delicassen'],

# %%
input_data = data.head(1)
import numpy as np

# %%
distances = kmeans.transform(input_data)
cluster_distance = distances[0, y_means[0]]

# Get the indices of the 5 closest data points
indices = np.argsort(y_means)[:5]

# Get the 5 closest data points
closest_data_points = data.iloc[indices]

# %%
# Out:
#    Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0        2       3  12669   9656     7561     214              2674
# 1        2       3   7057   9810     9568    1762              3293
# 2        2       3   6353   8808     7684    2405              3516
# 3        1       3  13265   1196     4221    6404               507
# 4        2       3  22615   5410     7198    3915              1777
# 5        2       3   9413   8259     5126     666              1795
# 6        2       3  12126   3199     6975     480              3140
# 7        2       3   7579   4956     9426    1669              3321
# 8        1       3   5963   3648     6192     425              1716
# 9        2       3   6006  11093    18881    1159              7425
#
#    Delicassen
# 0        1338
# 1        1776
# 2        7844
# 3        1788
# 4        5185
# 5        1451
# 6         545
# 7        2566
# 8         750
# 9        2098
